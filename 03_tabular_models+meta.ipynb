# %%
import numpy as np
import pandas as pd
from hyperopt import hp, tpe, Trials, fmin, STATUS_OK
import time
from catboost import CatBoostRegressor
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error, r2_score
from tqdm import tqdm
from sklearn.linear_model import Ridge
import joblib

# %%
train_df_end = np.load("train_df_end.npy")
val_df_end = np.load("val_df_end.npy")
test_df_end = np.load("test_df_end.npy")

# %%
train_df = pd.read_csv("train_df.csv")
val_df = pd.read_csv("val_df.csv")

# %%
y_train = train_df['log_salary_from']
y_val = val_df['log_salary_from']

# %% [markdown]
# ## CatBoostRegressor

# %%
print("\nЗапуск Hyperopt...")
start_time_hyperopt = time.time()

space = {
    'iterations': hp.quniform('iterations', 200, 1000, 50),
    'learning_rate': hp.uniform('learning_rate', 0.01, 0.9),
    'depth': hp.quniform('depth', 3, 5, 1),
    'l2_leaf_reg': hp.quniform('l2_leaf_reg', 0.1, 10.1, 1),
    'bagging_temperature': hp.quniform('bagging_temperature', 0.1, 1, 0.4)
}

def objective(params):
    model_params = {
        'iterations': int(params['iterations']),
        'depth': int(params['depth']),
        'learning_rate': params['learning_rate'],
        'l2_leaf_reg': params['l2_leaf_reg'],
        'bagging_temperature': params['bagging_temperature'],
        'od_wait': 100,
        'loss_function':'RMSE',
        'verbose': False
    }

    model = CatBoostRegressor(**model_params)

    scores = cross_val_score(model, train_df_end, y_train, 
                             cv=5, 
                             scoring='r2',
                             n_jobs=-1)
    
    r2_mean = float(np.mean(scores))

    hyperopt_pbar.update(1)

    return {'loss': -r2_mean, 'status': STATUS_OK, 'params': model_params}

n_iter_hyperopt = 15
hyperopt_pbar = tqdm(total=n_iter_hyperopt, desc="Hyperopt")

trials = Trials()
best_hyperopt = fmin(
    fn=objective,
    space=space,
    algo=tpe.suggest,
    max_evals=n_iter_hyperopt,
    trials=trials,
    verbose=0
)

hyperopt_pbar.close()

best_trial_idx = np.argmin([t['result']['loss'] for t in trials.trials])
best_params_hyperopt1 = trials.trials[best_trial_idx]['result']['params']

best_score_hyperopt = min([t['result']['loss'] for t in trials.trials])
time_hyperopt = time.time() - start_time_hyperopt

best_model_hyperopt = CatBoostRegressor(**best_params_hyperopt1)
best_model_hyperopt.fit(train_df_end, y_train)

y_test_pred_hyperopt = best_model_hyperopt.predict(val_df_end)

r2_val = r2_score(y_val, y_test_pred_hyperopt)

print(f"\nHyperopt завершен за {time_hyperopt:.2f} секунд")
print(f"Лучшие параметры: {best_params_hyperopt1}")
print(f"Лучший CV R2: {best_score_hyperopt:.4f}")
print(f"R2 на тестовых данных: {r2_val:.4f}")
# Out:
# Запуск Hyperopt...
# Hyperopt: 100%|████████████████████████████████████████████████████████████████████████| 15/15 [08:11<00:00, 32.75s/it]
# Hyperopt завершен за 491.22 секунд
# Лучшие параметры: {'iterations': 750, 'depth': 3, 'learning_rate': 0.2902730527551567, 'l2_leaf_reg': 10.0, 'bagging_temperature': 0.8, 'od_wait': 100, 'loss_function': 'RMSE', 'verbose': False}
# Лучший CV R2: -0.9360
# R2 на тестовых данных: 0.7718

# %%
r2_score(y_val, best_model_hyperopt.predict(val_df_end))
# Out:
# 0.7718218058046294

# %%
best_model_hyperopt.save_model("catboost_model.cbm")

# %%
# loaded_model = CatBoostRegressor()
# loaded_model.load_model("catboost_model.cbm")

# %% [markdown]
# ## XGBRegressor

# %%
from xgboost import XGBRegressor

# %%
space = {
    'n_estimators': hp.quniform('n_estimators', 200, 1000, 50),
    'learning_rate': hp.uniform('learning_rate', 0.01, 0.5),
    'max_depth': hp.quniform('max_depth', 2, 6, 1),
    'min_child_weight': hp.quniform('min_child_weight', 1, 10, 1),
    'subsample': hp.uniform('subsample', 0.5, 1.0),
    'colsample_bytree': hp.uniform('colsample_bytree', 0.5, 1.0),
}

def objective(params):
    params['n_estimators'] = int(params['n_estimators'])
    params['max_depth'] = int(params['max_depth'])
    params['min_child_weight'] = int(params['min_child_weight'])

    model = XGBRegressor(
        **params,
        verbosity=0,
        use_label_encoder=False,
        objective='reg:squarederror'  
    )

    scores = cross_val_score(
        model, 
        train_df_end, 
        y_train,
        cv=5,
        scoring='r2',
        n_jobs=-1
    )

    r2_mean = float(np.mean(scores))

    hyperopt_pbar.update(1)

    return {'loss': -r2_mean, 'status': STATUS_OK, 'params': params}

n_iter_hyperopt = 10
hyperopt_pbar = tqdm(total=n_iter_hyperopt, desc="Hyperopt")

trials = Trials()
best_hyperopt = fmin(
    fn=objective,
    space=space,
    algo=tpe.suggest,
    max_evals=n_iter_hyperopt,
    trials=trials,
    verbose=0
)

hyperopt_pbar.close()

best_trial_idx = np.argmin([t['result']['loss'] for t in trials.trials])
best_params_hyperopt3 = trials.trials[best_trial_idx]['result']['params']

best_score_hyperopt = min([t['result']['loss'] for t in trials.trials])
time_hyperopt = time.time() - start_time_hyperopt

best_model_hyperopt_xgb = XGBRegressor(
    **best_params_hyperopt3,
    verbosity=0,
    use_label_encoder=False,
    objective='reg:squarederror'
)
best_model_hyperopt_xgb.fit(train_df_end, y_train)

y_test_pred_hyperopt = best_model_hyperopt_xgb.predict(val_df_end)
r2_test = r2_score(y_val, y_test_pred_hyperopt)

print(f"\nHyperopt завершен за {time_hyperopt:.2f} секунд")
print(f"Лучшие параметры: {best_params_hyperopt3}")
print(f"Лучший CV R2: {r2_test:.4f}")
print(f"R2 на тестовых данных: {r2_test:.4f}")
# Out:
# Hyperopt: 100%|████████████████████████████████████████████████████████████████████████| 10/10 [05:34<00:00, 33.49s/it]
# Hyperopt завершен за 1364.80 секунд
# Лучшие параметры: {'colsample_bytree': 0.9823757057704589, 'learning_rate': 0.08787421454051206, 'max_depth': 2, 'min_child_weight': 8, 'n_estimators': 700, 'subsample': 0.5040233868954548}
# Лучший CV R2: 0.7742
# R2 на тестовых данных: 0.7742

# %%
best_model_hyperopt_xgb.save_model("xgb_model.json")

# %%
# loaded_model = XGBRegressor()
# loaded_model.load_model("xgb_model.json")
# y_pred = loaded_model.predict(test_df_end)

# %% [markdown]
# # Ridge

# %%
model = Ridge(alpha=1, random_state=42)
model.fit(train_df_end, y_train)
val_preds = model.predict(val_df_end)
r2_score(y_val, val_preds)
# Out:
# 0.7713051077908617

# %%
joblib.dump(model, "ridge_model.joblib")
# Out:
# ['ridge_model.joblib']

# %%
# loaded_model = joblib.load("ridge_model.joblib")
# y_pred = loaded_model.predict(test_df_end)

# %% [markdown]
# # Meta-model

# %%
# model = joblib.load("ridge_model.joblib")

# %%
# best_model_hyperopt_xgb = XGBRegressor()
# best_model_hyperopt_xgb.load_model("xgb_model.json")

# %%
# best_model_hyperopt = CatBoostRegressor()
# best_model_hyperopt.load_model("catboost_model.cbm")

# %%
cb_predictions_train = best_model_hyperopt.predict(train_df_end) 
cb_predictions_val = best_model_hyperopt.predict(val_df_end)
cb_predictions_test = best_model_hyperopt.predict(test_df_end)

# %%
xgb_predictions_train = best_model_hyperopt_xgb.predict(train_df_end)
xgb_predictions_val = best_model_hyperopt_xgb.predict(val_df_end)
xgb_predictions_test = best_model_hyperopt_xgb.predict(test_df_end)

# %%
ridge_predictions_train = model.predict(train_df_end)
ridge_predictions_val = model.predict(val_df_end)
ridge_predictions_test = model.predict(test_df_end)

# %%
bert_predictions_train = np.load("predictions_train_v2.npy")
bert_predictions_val = np.load("predictions_val_v2.npy")
bert_predictions_test = np.load("predictions_test_v2.npy")

# %%
meta_train = np.column_stack((bert_predictions_train, cb_predictions_train, xgb_predictions_train, ridge_predictions_train))
meta_val = np.column_stack((bert_predictions_val, cb_predictions_val, xgb_predictions_val, ridge_predictions_val))
meta_test = np.column_stack((bert_predictions_test, cb_predictions_test, xgb_predictions_test, ridge_predictions_test))

# %%
meta_model = Ridge(alpha=0.8, random_state=42)
meta_model.fit(meta_train, y_train)
val_preds = meta_model.predict(meta_val)
r2_score(y_val, val_preds)
# Out:
# 0.7636605228426843

# %%
joblib.dump(meta_model, "meta_model.joblib")
# Out:
# ['meta_model.joblib']

# %%
bert_predictions_test = np.load("predictions_test_v2.npy")

# %%
sam_sub = pd.read_csv('sample_submition.csv')

# %%
sam_sub['prediction'] = ridge_predictions_test

# %%
sam_sub.to_csv("sub_ridge.csv", index=False)

# %%
r2_train = [r2_score(y_train, cb_predictions_train)
            , r2_score(y_train, xgb_predictions_train)
            , r2_score(y_train, ridge_predictions_train)
            , r2_score(y_train, bert_predictions_train)
            , r2_score(y_train, meta_model.predict(meta_train))]

# %%
r2_val = [ r2_score(y_val, cb_predictions_val)
          , r2_score(y_val, xgb_predictions_val)
          , r2_score(y_val, ridge_predictions_val)
          , r2_score(y_val, bert_predictions_val)
          , r2_score(y_val, meta_model.predict(meta_val))]

# %%
r2_test = [0.779502, 0.785118, 0.783426, 0.772943, 0.769802]

# %%
df_res = pd.DataFrame({"Модели": ["CatBoostRegressor", "XGBRegressor", "Ridge", "Bert", "Meta model(над всеми)"]
            , "R2_train": r2_train
            , "R2_val": r2_val
            , "R2_test": r2_test
             })

# %%
df_res.style.highlight_max(subset= ['R2_train', 'R2_val', "R2_test"], axis=0, color='palegreen')
# Out:
# <style type="text/css">
# #T_0aa7c_row1_col2, #T_0aa7c_row1_col3, #T_0aa7c_row4_col1 {
#   background-color: palegreen;
# }
# </style>
# <table id="T_0aa7c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0aa7c_level0_col0" class="col_heading level0 col0" >Модели</th>
#       <th id="T_0aa7c_level0_col1" class="col_heading level0 col1" >R2_train</th>
#       <th id="T_0aa7c_level0_col2" class="col_heading level0 col2" >R2_val</th>
#       <th id="T_0aa7c_level0_col3" class="col_heading level0 col3" >R2_test</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0aa7c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0aa7c_row0_col0" class="data row0 col0" >CatBoostRegressor</td>
#       <td id="T_0aa7c_row0_col1" class="data row0 col1" >0.977065</td>
#       <td id="T_0aa7c_row0_col2" class="data row0 col2" >0.771822</td>
#       <td id="T_0aa7c_row0_col3" class="data row0 col3" >0.779502</td>
#     </tr>
#     <tr>
#       <th id="T_0aa7c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0aa7c_row1_col0" class="data row1 col0" >XGBRegressor</td>
#       <td id="T_0aa7c_row1_col1" class="data row1 col1" >0.957768</td>
#       <td id="T_0aa7c_row1_col2" class="data row1 col2" >0.774246</td>
#       <td id="T_0aa7c_row1_col3" class="data row1 col3" >0.785118</td>
#     </tr>
#     <tr>
#       <th id="T_0aa7c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0aa7c_row2_col0" class="data row2 col0" >Ridge</td>
#       <td id="T_0aa7c_row2_col1" class="data row2 col1" >0.947276</td>
#       <td id="T_0aa7c_row2_col2" class="data row2 col2" >0.771305</td>
#       <td id="T_0aa7c_row2_col3" class="data row2 col3" >0.783426</td>
#     </tr>
#     <tr>
#       <th id="T_0aa7c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0aa7c_row3_col0" class="data row3 col0" >Bert</td>
#       <td id="T_0aa7c_row3_col1" class="data row3 col1" >0.937226</td>
#       <td id="T_0aa7c_row3_col2" class="data row3 col2" >0.762362</td>
#       <td id="T_0aa7c_row3_col3" class="data row3 col3" >0.772943</td>
#     </tr>
#     <tr>
#       <th id="T_0aa7c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0aa7c_row4_col0" class="data row4 col0" >Meta model(над всеми)</td>
#       <td id="T_0aa7c_row4_col1" class="data row4 col1" >0.982872</td>
#       <td id="T_0aa7c_row4_col2" class="data row4 col2" >0.763661</td>
#       <td id="T_0aa7c_row4_col3" class="data row4 col3" >0.769802</td>
#     </tr>
#   </tbody>
# </table>
